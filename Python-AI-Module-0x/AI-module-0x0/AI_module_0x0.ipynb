# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-f93ea7fe-4fcf-4956-8370-88647ba10f15" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-f93ea7fe-4fcf-4956-8370-88647ba10f15">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
# You need to import the pandas and seaborn library
import pandas as pd
import seaborn as sns

# %%
# Charger le fichier CSV
data = pd.read_csv("Salary_dataset.csv")

# Configurer le thème de Seaborn
sns.set_theme(style="darkgrid")

# Tracer le jointplot avec nuage de points et histogrammes
g = sns.jointplot(x="YearsExperience", y="Salary", data=data,
                  kind="scatter", color="m", height=7)

# %%
# Read the data from the CSV file with read from pandas
data = pd.read_csv("Salary_dataset.csv")


# Configure the style
sns.set_theme()

# Plot the data points with seaborn
data.plot(kind="scatter", x="YearsExperience", y="Salary")
# Out:
# <Axes: xlabel='YearsExperience', ylabel='Salary'>

# %%
# We're going to use this library and find out how it works on the Internet
from sklearn.linear_model import LinearRegression

# Separate the features (YearsExperience) from the target variable (Salary)
X = data[['YearsExperience']]
y = data['Salary']

# Create a linear regression model
regression = LinearRegression()
# Train the model
regression.fit(X, y)
# Predict the Salary values based on YearsExperience
predictions = regression.predict(X)

# %%
#You have to reproduce this graph

# %%
# Create a linear regression plot using lmplot
sns.scatterplot(x="YearsExperience", y="Salary", data=data, color='lightblue').set(title='Linear Regression: Years of Experience vs Salary')
# Set labels and title
sns.regplot(x="YearsExperience", y="Salary", data=data, ci=95)
# Out:
# <Axes: title={'center': 'Linear Regression: Years of Experience vs Salary'}, xlabel='YearsExperience', ylabel='Salary'>

# %%
# You should have these results with 10 years of expertise, so it's up to you to do your own tests

# %%
# Years of experience of the person you want to predict the salary for
years_experience = 10

# Predict the salary
predicted_df = pd.DataFrame({'YearsExperience': [years_experience]})

predicted_salary = regression.predict(predicted_df)

# Display the predicted salary
print("Le salaire prédit pour {} années d'expérience est : {}".format(years_experience, predicted_salary[0]))
# Out:
# Le salaire prédit pour 10 années d'expérience est : 119347.82718107398
